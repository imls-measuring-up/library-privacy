# %% [markdown]
# # Test notebook for evaluation of Measuring Up privacy leakage analysis

# %%
from lxml import html
import requests
import urllib2
from bs4 import BeautifulSoup
import csv
from urlparse import urlsplit, urlunsplit
import datetime
import os
import json

# %%
# Define Variables

# Limited test of the partial collection of libraries in the CSV file
limitedTest = True


# Get Member Library Names and URLs
dataDLF = 'https://www.diglib.org/members/'
dataARL = 'http://www.arl.org/membership/list-of-arl-members'
dataOCLC = 'http://www.oclc.org/research/partnership/roster.html'

# data file containing the list of libraries from which to retrieve pages
libraryFile = "data_all_library.csv"

# root path for writing out the retrieved files
writePath = "fileStore"
tablePath = "tableStore"

# %%
# set the execution time to use in creating the subdirectory in which the retrieved HTML files will be placed
runTime = datetime.datetime.now().isoformat()

# create the subdirectory where the retrieved files will be saved
currentWriteFilePath = writePath + "/" + runTime
if not os.path.isdir(currentWriteFilePath):
    os.mkdir(currentWriteFilePath)

# create the subdirectory where the generated output tables will be saved
tableWriteFilePath = tablePath + "/" + runTime
if not os.path.isdir(tableWriteFilePath):
    os.mkdir(tableWriteFilePath)

# Connect to the CSV file containing the list of libraries to test
with open(libraryFile, 'rb') as csvfile:
    libraryReader = csv.DictReader(csvfile, delimiter=",", quotechar='"')
    i=0
    outputDict = {}
    for libraryRow in libraryReader:
        i+=1
        print "(" + str(i) + ") " + "Processing: " + libraryRow['school']
        
        # break the provided URL into components so that secure and insecure requests can be generated
        scheme,host,path,query,fragment = urlsplit(libraryRow['url'])
        insecureLink = urlunsplit(('http',host,path,query,fragment))
        secureLink = urlunsplit(('https',host,path,query,fragment))
        print "Insecure URL: " + insecureLink
        print "Secure URL: " + secureLink
        
        # request the insecure page and process its content
        try:
            insecurePageRequest = requests.get(insecureLink, allow_redirects=True)
            pageHeaders = insecurePageRequest.headers
            pageCookies = dict(insecurePageRequest.cookies)
            pageRedirectHist = insecurePageRequest.history
            pageRedirectEndURL = insecurePageRequest.url
            pageHTML = insecurePageRequest.content
            pageSoup = BeautifulSoup(pageHTML,'html.parser')
            imageURLs = []
            scriptURLs = []
            for image in pageSoup.find_all('img'):
                imageURLs.append(image.get('src'))
            for script in pageSoup.find_all('script'):
                scriptURLs.append(script.get('src'))
            if urlsplit(pageRedirectEndURL)[0] == 'https':
                pageSecureRedirect = True
            else:
                pageSecureRedirect = False
            #print pageHeaders
            #print pageCookies
            #print pageRedirectHist
            #print pageRedirectEndURL
            #print pageSecureRedirect
            #print imageURLs
            #print scriptURLs
            # write out the retrieved HTML file
            thisFileWriteFilename = "insecure_" + host + ".html"
            thisFileFullPathWFilename = currentWriteFilePath+'/'+thisFileWriteFilename
            f = open(thisFileFullPathWFilename, 'w')
            f.write(pageHTML)
            f.close()
            # generate the outputDict entry for this web site
            thisDict = {insecureLink: {
                    'pageHeaders': pageHeaders,
                    'pageCookies': pageCookies,
                    'pageRedirectHist': pageRedirectHist,
                    'pageRedirectEndURL': pageRedirectEndURL,
                    'imageURLs': imageURLs,
                    'scriptURLs': scriptURLs
                }}
            #print thisDict
            outputDict.update(thisDict)
        except:
            print "something went wrong - more soon ;)"
        
        # request the secure page and process its content
        try:
            securePageRequest = requests.get(secureLink, allow_redirects=True)
            pageHeaders = securePageRequest.headers
            pageCookies = dict(securePageRequest.cookies)
            pageRedirectHist = securePageRequest.history
            pageRedirectEndURL = securePageRequest.url
            pageHTML = securePageRequest.content
            pageSoup = BeautifulSoup(pageHTML,'html.parser')
            imageURLs = []
            scriptURLs = []
            for image in pageSoup.find_all('img'):
                imageURLs.append(image.get('src'))
            for script in pageSoup.find_all('script'):
                scriptURLs.append(script.get('src'))
            if urlsplit(pageRedirectEndURL)[0] == 'https':
                pageSecureRedirect = True
            else:
                pageSecureRedirect = False
            #print pageHeaders
            #print pageCookies
            #print pageRedirectHist
            #print pageRedirectEndURL
            #print pageSecureRedirect
            #print imageURLs
            #print scriptURLs
            # write out the retrieved HTML file
            thisFileWriteFilename = "secure_" + host + ".html"
            thisFileFullPathWFilename = currentWriteFilePath+'/'+thisFileWriteFilename
            f = open(thisFileFullPathWFilename, 'w')
            f.write(pageHTML)
            f.close()
            # generate the outputDict entry for this web site
            thisDict = {secureLink: {
                    'pageHeaders': pageHeaders,
                    'pageCookies': pageCookies,
                    'pageRedirectHist': pageRedirectHist,
                    'pageRedirectEndURL': pageRedirectEndURL,
                    'imageURLs': imageURLs,
                    'scriptURLs': scriptURLs
                }}
            #print thisDict
            outputDict.update(thisDict)
        except:
            print "something went wrong - more soon ;)"
        

        print
        print "======================================"
        if limitedTest and i>10:
            break
# Out:
# (1) Processing: University of Alabama Libraries
# Insecure URL: http://www.lib.ua.edu/
# Secure URL: https://www.lib.ua.edu/
# {'http://www.lib.ua.edu/': {'pageHeaders': {'X-Powered-By': 'PHP/5.3.17', 'Transfer-Encoding': 'chunked', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=100', 'Server': 'Apache/2.2.12 (Linux/SUSE)', 'Connection': 'Keep-Alive', 'Link': '<https://www.lib.ua.edu/wp-json/>; rel="https://api.w.org/", <https://www.lib.ua.edu/>; rel=shortlink', 'Date': 'Wed, 27 Jul 2016 04:44:27 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'X-Pingback': 'https://www.lib.ua.edu/xmlrpc.php'}, 'scriptURLs': [None, None, u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/local.js?ver=7921d642b236f108b809cb1bca816257', None, u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/vendor/modernizr.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-animate.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-route.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-resource.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-sanitize.min.js', u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/scripts_bower.min.js?9dd37d9643becae227398fff92ec450b', u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/scripts.min.js?3903579a80d92c3bf1fb001cc7deef33', u'https://www.lib.ua.edu/wp-includes/js/wp-embed.min.js?ver=7921d642b236f108b809cb1bca816257', None], 'pageCookies': {}, 'pageRedirectEndURL': u'https://www.lib.ua.edu/', 'pageRedirectHist': [<Response [301]>], 'imageURLs': [u'/wp-content/themes/roots-ualib/assets/img/new-ualib-logo.png', u'//www.lib.ua.edu/wp-content/themes/roots-ualib/assets/img/ua-official-logo.png', u'//www.lib.ua.edu/wp-content/themes/roots-ualib/assets/img/fdlp_logo.png', u'//www.lib.ua.edu/wp-content/themes/roots-ualib/assets/img/HT-logo.png']}}
# {'https://www.lib.ua.edu/': {'pageHeaders': {'X-Powered-By': 'PHP/5.3.17', 'Transfer-Encoding': 'chunked', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=100', 'Server': 'Apache/2.2.12 (Linux/SUSE)', 'Connection': 'Keep-Alive', 'Link': '<https://www.lib.ua.edu/wp-json/>; rel="https://api.w.org/", <https://www.lib.ua.edu/>; rel=shortlink', 'Date': 'Wed, 27 Jul 2016 04:44:28 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'X-Pingback': 'https://www.lib.ua.edu/xmlrpc.php'}, 'scriptURLs': [None, None, u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/local.js?ver=7921d642b236f108b809cb1bca816257', None, u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/vendor/modernizr.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-animate.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-route.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-resource.min.js', u'//cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.28/angular-sanitize.min.js', u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/scripts_bower.min.js?9dd37d9643becae227398fff92ec450b', u'https://www.lib.ua.edu/wp-content/themes/roots-ualib/assets/js/scripts.min.js?3903579a80d92c3bf1fb001cc7deef33', u'https://www.lib.ua.edu/wp-includes/js/wp-embed.min.js?ver=7921d642b236f108b809cb1bca816257', None], 'pageCookies': {}, 'pageRedirectEndURL': u'https://www.lib.ua.edu/', 'pageRedirectHist': [], 'imageURLs': [u'/wp-content/themes/roots-ualib/assets/img/new-ualib-logo.png', u'//www.lib.ua.edu/wp-content/themes/roots-ualib/assets/img/ua-official-logo.png', u'//www.lib.ua.edu/wp-content/themes/roots-ualib/assets/img/fdlp_logo.png', u'//www.lib.ua.edu/wp-content/themes/roots-ualib/assets/img/HT-logo.png']}}
#
# ======================================
# (2) Processing: University at Albany, SUNY, Libraries
# Insecure URL: http://library.albany.edu/
# Secure URL: https://library.albany.edu/
# {'http://library.albany.edu/': {'pageHeaders': {'Content-Length': '40809', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'SESS569c5c43d8854a817b0e628c0e0a14d0=r82lqbvoicmmdferbsfl5m81qmv899n1; expires=Fri, 19-Aug-2016 08:17:55 GMT; path=/; domain=library.albany.edu', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Server': 'Microsoft-IIS/7.5', 'Last-Modified': 'Wed, 27 Jul 2016 04:44:35 GMT', 'Cache-Control': 'store, no-cache, must-revalidate,post-check=0, pre-check=0', 'Date': 'Wed, 27 Jul 2016 04:44:35 GMT', 'Content-Type': 'text/html; charset=utf-8'}, 'scriptURLs': [u'/libdru/scripts/jquery.js', u'/libdru/scripts/jquery-ui.js', None, u'/misc/jquery.js?3', u'/misc/drupal.js?3', u'/sites/all/modules/dhtml_menu/dhtml_menu.js?3', u'/sites/all/modules/nice_menus/superfish/js/superfish.js?3', u'/sites/all/modules/nice_menus/superfish/js/jquery.bgiframe.min.js?3', u'/sites/all/modules/nice_menus/superfish/js/jquery.hoverIntent.minified.js?3', u'/sites/all/modules/nice_menus/nice_menus.js?3', u'/sites/all/modules/panels/js/panels.js?3', u'/sites/all/modules/poormanscron/poormanscron.js?3', u'/sites/all/themes/adaptivetheme/adaptivetheme/js/at-scripts.js?3', None, None, u'/angelfish.js', None, u'/sites/all/themes/ualibrary4/scripts/search.js', u'/libdru/scripts/coin-slider.min.js', u'/sites/all/themes/ualibrary4/scripts/minisearch.js', u'/sites/all/themes/ualibrary4/scripts/ualibraryv4.js', u'/sites/all/themes/ualibrary4/scripts/hours.js', u'/libdru/scripts/hours/libhours.js', None, u'/sites/all/themes/ualibrary4/scripts/db.ac.js', None, None, None], 'pageCookies': {'SESS569c5c43d8854a817b0e628c0e0a14d0': 'r82lqbvoicmmdferbsfl5m81qmv899n1'}, 'pageRedirectEndURL': u'http://library.albany.edu/', 'pageRedirectHist': [], 'imageURLs': [u'/sites/all/themes/ualibrary4/images/banners/ualib_bannerv4_bk.jpg', u'/sites/all/themes/ualibrary4/images/banners/ualib_askusv4.png', u'/sites/all/themes/ualibrary/images/icons/breadright.gif', u'/libdru/images/icons/nextarrowright36.png', u'/sites/all/themes/ualibrary4/images/cs/2-EOPSummer.jpg', u'/sites/all/themes/ualibrary4/images/cs/latheatre.jpg', u'/sites/all/themes/ualibrary4/images/cs/student_press.jpg', u'/sites/all/themes/ualibrary4/images/cs/chairslider.jpg', u'/sites/all/themes/ualibrary4/images/cs/ieeeseconddraft.jpg', u'/sites/all/themes/ualibrary4/images/cs/nineteenthcentury.jpg', u'/sites/all/themes/ualibrary4/images/cs/cs009.jpg', u'/sites/all/themes/ualibrary4/images/cs/instagram.jpg', u'/sites/all/themes/ualibrary4/images/cs/cs004.jpg', u'/sites/all/themes/ualibrary/images/icons/libhoursclock.png', u'/sites/all/themes/ualibrary4/images/footers/msite_icon.png', u'/sites/all/themes/ualibrary4/images/footers/yt_icon.png', u'/libdru/images/icons/pintresticon28.png', u'/sites/all/themes/ualibrary4/images/icons/lib_twitter_icon.png', u'/sites/all/themes/ualibrary4/images/footers/fb_icon.png', u'/sites/all/themes/ualibrary4/images/footers/instagram.png', u'/sites/all/themes/ualibrary4/images/footers/yt_icon.png', u'/libdru/images/icons/pintresticon28.png', u'/sites/all/themes/ualibrary4/images/icons/lib_twitter_icon.png', u'/sites/all/themes/ualibrary4/images/footers/fb_icon.png']}}
# {'https://library.albany.edu/': {'pageHeaders': {'Content-Length': '40809', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'SESS569c5c43d8854a817b0e628c0e0a14d0=7detohrtqem1h68cpas5146hb7glur57; expires=Fri, 19-Aug-2016 08:18:00 GMT; path=/; domain=library.albany.edu', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Server': 'Microsoft-IIS/7.5', 'Last-Modified': 'Wed, 27 Jul 2016 04:44:40 GMT', 'Cache-Control': 'store, no-cache, must-revalidate,post-check=0, pre-check=0', 'Date': 'Wed, 27 Jul 2016 04:44:40 GMT', 'Content-Type': 'text/html; charset=utf-8'}, 'scriptURLs': [u'/libdru/scripts/jquery.js', u'/libdru/scripts/jquery-ui.js', None, u'/misc/jquery.js?3', u'/misc/drupal.js?3', u'/sites/all/modules/dhtml_menu/dhtml_menu.js?3', u'/sites/all/modules/nice_menus/superfish/js/superfish.js?3', u'/sites/all/modules/nice_menus/superfish/js/jquery.bgiframe.min.js?3', u'/sites/all/modules/nice_menus/superfish/js/jquery.hoverIntent.minified.js?3', u'/sites/all/modules/nice_menus/nice_menus.js?3', u'/sites/all/modules/panels/js/panels.js?3', u'/sites/all/modules/poormanscron/poormanscron.js?3', u'/sites/all/themes/adaptivetheme/adaptivetheme/js/at-scripts.js?3', None, None, u'/angelfish.js', None, u'/sites/all/themes/ualibrary4/scripts/search.js', u'/libdru/scripts/coin-slider.min.js', u'/sites/all/themes/ualibrary4/scripts/minisearch.js', u'/sites/all/themes/ualibrary4/scripts/ualibraryv4.js', u'/sites/all/themes/ualibrary4/scripts/hours.js', u'/libdru/scripts/hours/libhours.js', None, u'/sites/all/themes/ualibrary4/scripts/db.ac.js', None, None, None], 'pageCookies': {'SESS569c5c43d8854a817b0e628c0e0a14d0': '7detohrtqem1h68cpas5146hb7glur57'}, 'pageRedirectEndURL': u'https://library.albany.edu/', 'pageRedirectHist': [], 'imageURLs': [u'/sites/all/themes/ualibrary4/images/banners/ualib_bannerv4_bk.jpg', u'/sites/all/themes/ualibrary4/images/banners/ualib_askusv4.png', u'/sites/all/themes/ualibrary/images/icons/breadright.gif', u'/libdru/images/icons/nextarrowright36.png', u'/sites/all/themes/ualibrary4/images/cs/2-EOPSummer.jpg', u'/sites/all/themes/ualibrary4/images/cs/latheatre.jpg', u'/sites/all/themes/ualibrary4/images/cs/student_press.jpg', u'/sites/all/themes/ualibrary4/images/cs/chairslider.jpg', u'/sites/all/themes/ualibrary4/images/cs/ieeeseconddraft.jpg', u'/sites/all/themes/ualibrary4/images/cs/nineteenthcentury.jpg', u'/sites/all/themes/ualibrary4/images/cs/cs009.jpg', u'/sites/all/themes/ualibrary4/images/cs/instagram.jpg', u'/sites/all/themes/ualibrary4/images/cs/cs004.jpg', u'/sites/all/themes/ualibrary/images/icons/libhoursclock.png', u'/sites/all/themes/ualibrary4/images/footers/msite_icon.png', u'/sites/all/themes/ualibrary4/images/footers/yt_icon.png', u'/libdru/images/icons/pintresticon28.png', u'/sites/all/themes/ualibrary4/images/icons/lib_twitter_icon.png', u'/sites/all/themes/ualibrary4/images/footers/fb_icon.png', u'/sites/all/themes/ualibrary4/images/footers/instagram.png', u'/sites/all/themes/ualibrary4/images/footers/yt_icon.png', u'/libdru/images/icons/pintresticon28.png', u'/sites/all/themes/ualibrary4/images/icons/lib_twitter_icon.png', u'/sites/all/themes/ualibrary4/images/footers/fb_icon.png']}}
#
# ======================================
# (3) Processing: University of Alberta Libraries
# Insecure URL: http://www.library.ualberta.ca/
# Secure URL: https://www.library.ualberta.ca/
# {'http://www.library.ualberta.ca/': {'pageHeaders': {'Status': '200 OK', 'X-Request-Id': 'f4846bbf-2cd0-4529-82d9-33be8ee67ba3', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Powered-By': 'Phusion Passenger 4.0.58', 'Set-Cookie': '_session_id=88cafe60495f2d7be42d05bc54d21c00; path=/; expires=Wed, 27 Jul 2016 06:44:43 -0000; HttpOnly', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Content-Length': '11214', 'Server': 'Apache/2.2.15 (CentOS)', 'X-Runtime': '0.048564', 'ETag': 'W/"3e1130b697728b8662d6f1d6f894e9c2"', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Date': 'Wed, 27 Jul 2016 04:44:43 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'text/html; charset=utf-8'}, 'scriptURLs': [u'/assets/application-2d59d0144e62455ad4c3dd37d7cf9fd5079df58dd63225cedbeda8c798d7ec8c.js', u'/assets/ualib-home-cbe1aad6bad383c4c6d62ee1ddf4ac34c550539ef1a4ee193bc12ce6fe4c17c3.js', u'https://hours.library.ualberta.ca/widget-hours-current.php', None, None, None], 'pageCookies': {'_session_id': '88cafe60495f2d7be42d05bc54d21c00'}, 'pageRedirectEndURL': u'https://www.library.ualberta.ca/', 'pageRedirectHist': [<Response [302]>], 'imageURLs': [u'/assets/ualib-logo-5558a8a69dad6d8c9daca685f59d31b66682b69f1cee4674d55ce47a89dd6ea6.png', u'https://www2.library.ualberta.ca/2015assets/lib-icons/4.png', u'https://www2.library.ualberta.ca/2015assets/webtile-vestiges-histofmed.jpg', u'https://www2.library.ualberta.ca/2015assets/ual-collage.jpg', u'https://www2.library.ualberta.ca/2015assets/share-air-web-tile.png', u'https://www2.library.ualberta.ca/2015assets/staff-photos/sandra-shores.jpg', u'https://www2.library.ualberta.ca/2015assets/facebook-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/youtube-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/flickr-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/Instagram_Icon.png', u'https://www2.library.ualberta.ca/2015assets/github-icon.png', u'https://www2.library.ualberta.ca/2015assets/facebook-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/youtube-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/flickr-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/Instagram_Icon.png', u'https://www2.library.ualberta.ca/2015assets/github-icon.png', u'/assets/cc-f46d7b11bac0d593eab6a828e92d3bacce2c096cd348508329dbc373f74619d0.png']}}
# {'https://www.library.ualberta.ca/': {'pageHeaders': {'Status': '200 OK', 'X-Request-Id': '4179a428-4b35-4698-aef3-d0c21de89196', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Powered-By': 'Phusion Passenger 4.0.58', 'Set-Cookie': '_session_id=8e4a5249c53f044e0f3b6af99f85225d; path=/; expires=Wed, 27 Jul 2016 06:44:43 -0000; HttpOnly', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Content-Length': '11216', 'Server': 'Apache/2.2.15 (CentOS)', 'X-Runtime': '0.054007', 'ETag': 'W/"e19b974469b26eb15e81058b96f9fb5b"', 'Cache-Control': 'max-age=0, private, must-revalidate', 'Date': 'Wed, 27 Jul 2016 04:44:43 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'text/html; charset=utf-8'}, 'scriptURLs': [u'/assets/application-2d59d0144e62455ad4c3dd37d7cf9fd5079df58dd63225cedbeda8c798d7ec8c.js', u'/assets/ualib-home-cbe1aad6bad383c4c6d62ee1ddf4ac34c550539ef1a4ee193bc12ce6fe4c17c3.js', u'https://hours.library.ualberta.ca/widget-hours-current.php', None, None, None], 'pageCookies': {'_session_id': '8e4a5249c53f044e0f3b6af99f85225d'}, 'pageRedirectEndURL': u'https://www.library.ualberta.ca/', 'pageRedirectHist': [], 'imageURLs': [u'/assets/ualib-logo-5558a8a69dad6d8c9daca685f59d31b66682b69f1cee4674d55ce47a89dd6ea6.png', u'https://www2.library.ualberta.ca/2015assets/lib-icons/4.png', u'https://www2.library.ualberta.ca/2015assets/webtile-vestiges-histofmed.jpg', u'https://www2.library.ualberta.ca/2015assets/ual-collage.jpg', u'https://www2.library.ualberta.ca/2015assets/share-air-web-tile.png', u'https://www2.library.ualberta.ca/2015assets/staff-photos/sandra-shores.jpg', u'https://www2.library.ualberta.ca/2015assets/facebook-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/youtube-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/flickr-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/Instagram_Icon.png', u'https://www2.library.ualberta.ca/2015assets/github-icon.png', u'https://www2.library.ualberta.ca/2015assets/facebook-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/youtube-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/flickr-icon_normal.png', u'https://www2.library.ualberta.ca/2015assets/Instagram_Icon.png', u'https://www2.library.ualberta.ca/2015assets/github-icon.png', u'/assets/cc-f46d7b11bac0d593eab6a828e92d3bacce2c096cd348508329dbc373f74619d0.png']}}
#
# ======================================
# (4) Processing: University of Arizona Libraries
# Insecure URL: http://www.library.arizona.edu/
# Secure URL: https://www.library.arizona.edu/
# {'http://www.library.arizona.edu/': {'pageHeaders': {'Content-Length': '12290', 'X-Drupal-Cache': 'HIT', 'Content-Language': 'en', 'Content-Encoding': 'gzip', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Vary': 'Cookie,Accept-Encoding', 'Keep-Alive': 'timeout=5, max=100', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Last-Modified': 'Wed, 27 Jul 2016 04:00:09 GMT', 'Connection': 'Keep-Alive', 'Etag': '"1469592009-0-gzip"', 'Link': '<http://new.library.arizona.edu/>; rel="canonical",<http://new.library.arizona.edu/>; rel="shortlink"', 'X-UA-Compatible': 'IE=Edge,chrome=1', 'X-Powered-By': 'PHP/5.5.9-1ubuntu4.17', 'Cache-Control': 'public, max-age=7200', 'Date': 'Wed, 27 Jul 2016 04:44:44 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'text/html; charset=utf-8', 'X-Generator': 'Drupal 7 (http://drupal.org)'}, 'scriptURLs': [u'http://new.library.arizona.edu/sites/default/files/js/js_MpKfe1sTh5JIVGCZ17DsAuT1rqAC38MLLlkjqjQ1X_k.js', u'http://new.library.arizona.edu/sites/default/files/js/js_H7q2xORKmR9AN8Qx5spKEIBp7R_wG2apAswJoCUZY7I.js', u'http://new.library.arizona.edu/sites/default/files/js/js_Cl0RumpiVc-4xPZgT5waU8dKTf-obio3uYy0FdssRD8.js', None, u'http://new.library.arizona.edu/sites/default/files/js/js_KdJf5b3FnMdaLoNej4Nz9T_Yms275viqaQhlOctwrmg.js', None, u'http://new.library.arizona.edu/sites/default/files/js/js_I8yX6RYPZb7AtMcDUA3QKDZqVkvEn35ED11_1i7vVpc.js', None, None, u'http://new.library.arizona.edu/sites/default/files/js/js_BGDFi4VC3FDO-et9OK356L1EO-laDW_b7OSHkS6rx8g.js', u'http://new.library.arizona.edu/sites/default/files/js/js_HKPSomSY4ZsGotpSazcA5xr2FF44tG9_pUBWryKtNJ4.js', None, None, u'http://new.library.arizona.edu/sites/default/files/js/js_ZS6dLuY7V6C3m5F4bpQ22p32KXGgRgRvrc_7MRtwbKc.js', None, None, u'http://new.library.arizona.edu/sites/default/files/js/js_PsUZFECBunCwJ4mX_UxRXM-OtkUIKjLHPU55njOvc2o.js'], 'pageCookies': {}, 'pageRedirectEndURL': u'http://new.library.arizona.edu', 'pageRedirectHist': [<Response [302]>], 'imageURLs': [u'http://new.library.arizona.edu/sites/all/modules/features/ual_rooms_spaces/small_group_study.jpg', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/ispace-workshops.jpg?itok=k6-z87uy', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/2016_fall_event_brochure_cabdiv_0.jpg?itok=JKanDBEj', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/openstax.jpg?itok=ZLxAgNGz', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/azu_da300_e48_1827_v3_pg001_m_0.jpg?itok=1c6WBpoo', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/library-cats-tech-breakfast.jpg?itok=pJkI6vVJ', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/summer-hours_0.jpg?itok=cpM7YRNG', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/ua-press-summer-picks.jpg?itok=Pei0QOZa', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/open-access.jpg?itok=TV7rP3Hm', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/student_studying.jpg?itok=H32MU-I2', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/stream-movie_0.jpg?itok=6coCCkb3']}}
# {'https://www.library.arizona.edu/': {'pageHeaders': {'Content-Length': '12290', 'X-Drupal-Cache': 'HIT', 'Content-Language': 'en', 'Content-Encoding': 'gzip', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Vary': 'Cookie,Accept-Encoding', 'Keep-Alive': 'timeout=5, max=100', 'Server': 'Apache/2.4.7 (Ubuntu)', 'Last-Modified': 'Wed, 27 Jul 2016 04:00:09 GMT', 'Connection': 'Keep-Alive', 'Etag': '"1469592009-0-gzip"', 'Link': '<http://new.library.arizona.edu/>; rel="canonical",<http://new.library.arizona.edu/>; rel="shortlink"', 'X-UA-Compatible': 'IE=Edge,chrome=1', 'X-Powered-By': 'PHP/5.5.9-1ubuntu4.17', 'Cache-Control': 'public, max-age=7200', 'Date': 'Wed, 27 Jul 2016 04:44:44 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'text/html; charset=utf-8', 'X-Generator': 'Drupal 7 (http://drupal.org)'}, 'scriptURLs': [u'http://new.library.arizona.edu/sites/default/files/js/js_MpKfe1sTh5JIVGCZ17DsAuT1rqAC38MLLlkjqjQ1X_k.js', u'http://new.library.arizona.edu/sites/default/files/js/js_H7q2xORKmR9AN8Qx5spKEIBp7R_wG2apAswJoCUZY7I.js', u'http://new.library.arizona.edu/sites/default/files/js/js_Cl0RumpiVc-4xPZgT5waU8dKTf-obio3uYy0FdssRD8.js', None, u'http://new.library.arizona.edu/sites/default/files/js/js_KdJf5b3FnMdaLoNej4Nz9T_Yms275viqaQhlOctwrmg.js', None, u'http://new.library.arizona.edu/sites/default/files/js/js_I8yX6RYPZb7AtMcDUA3QKDZqVkvEn35ED11_1i7vVpc.js', None, None, u'http://new.library.arizona.edu/sites/default/files/js/js_BGDFi4VC3FDO-et9OK356L1EO-laDW_b7OSHkS6rx8g.js', u'http://new.library.arizona.edu/sites/default/files/js/js_HKPSomSY4ZsGotpSazcA5xr2FF44tG9_pUBWryKtNJ4.js', None, None, u'http://new.library.arizona.edu/sites/default/files/js/js_ZS6dLuY7V6C3m5F4bpQ22p32KXGgRgRvrc_7MRtwbKc.js', None, None, u'http://new.library.arizona.edu/sites/default/files/js/js_PsUZFECBunCwJ4mX_UxRXM-OtkUIKjLHPU55njOvc2o.js'], 'pageCookies': {}, 'pageRedirectEndURL': u'http://new.library.arizona.edu', 'pageRedirectHist': [<Response [302]>], 'imageURLs': [u'http://new.library.arizona.edu/sites/all/modules/features/ual_rooms_spaces/small_group_study.jpg', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/ispace-workshops.jpg?itok=k6-z87uy', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/2016_fall_event_brochure_cabdiv_0.jpg?itok=JKanDBEj', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/openstax.jpg?itok=ZLxAgNGz', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/azu_da300_e48_1827_v3_pg001_m_0.jpg?itok=1c6WBpoo', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/library-cats-tech-breakfast.jpg?itok=pJkI6vVJ', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/summer-hours_0.jpg?itok=cpM7YRNG', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/ua-press-summer-picks.jpg?itok=Pei0QOZa', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/open-access.jpg?itok=TV7rP3Hm', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/student_studying.jpg?itok=H32MU-I2', u'http://new.library.arizona.edu/sites/default/files/styles/medium/public/stream-movie_0.jpg?itok=6coCCkb3']}}
#
# ======================================
# (5) Processing: Arizona State University Libraries
# Insecure URL: http://lib.asu.edu/
# Secure URL: https://lib.asu.edu/
# {'http://lib.asu.edu/': {'pageHeaders': {'Content-Length': '49875', 'X-Drupal-Cache': 'MISS', 'Last-Modified': 'Wed, 27 Jul 2016 04:37:30 GMT', 'Etag': 'W/"1469594250-0"', 'X-Pantheon-Styx-Hostname': 'styx37bdde9b', 'Content-Language': 'en', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'X-Styx-Version': 'StyxGo', 'X-Styx-Req-Id': 'styx-0e11921113afe30760031e7e071d192c', 'Date': 'Wed, 27 Jul 2016 04:37:31 GMT', 'Age': '433', 'X-Varnish': '58343491 97421017', 'Accept-Ranges': 'bytes', 'Server': 'nginx', 'Connection': 'keep-alive', 'X-Pantheon-Endpoint': '60f10b55-cd42-471f-a128-b1576f728538', 'Via': '1.1 varnish-v4', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding, Cookie, Cookie', 'Cache-Control': 'public, max-age=900', 'Content-Type': 'text/html; charset=utf-8', 'X-Generator': 'Drupal 7 (http://drupal.org)'}, 'scriptURLs': [None, None, None, u'//www.asu.edu/asuthemes/4.3/js/asu_header.min.js?v0.22', u'https://lib.asu.edu/sites/default/files/js/js_JLxuxbhhrFRy-sBnijHkR0TGGHgiukMPv94zvDWgQ3g.js', u'https://lib.asu.edu/sites/default/files/js/js_vPfI4qcVjTAPaUE2GX9IXR-oHPw5HBeHmwoIGfDl2HM.js', u'https://lib.asu.edu/sites/default/files/js/js_ZwtHh_UtMhEyIZ7P23uU_tO_tZHXgPG1rk11b_m8s9Y.js', None, None, u'https://lib.asu.edu/sites/default/files/js/js_qqhgYInYpIKc_wtVcwoImiEHiarKSSm4NxmsipAr8D4.js', None, u'https://lib.asu.edu/sites/default/files/js/js_a_XWH2S1EQaU85ypMDyQGiUfzPFez1IOZKxHnhGkv3E.js', None, u'https://lib.asu.edu/sites/default/files/js/js_mgDZNIxOWdpdUe3_wc1OM37QuUmqgsMggaIH1JcGAn4.js', None, None, None, None, None, None, None, None, None, None, None, None, u'//apps.lib.asu.edu/newbooks/js/bookshelf.js', u'//apps.lib.asu.edu/newbooks/js/newbook_image_list.js', u'//apps.lib.asu.edu/newbooks/js/virtualbookshelf.js', u'//apps.lib.asu.edu/newbooks/js/hours.js', u'https://lib.asu.edu/sites/default/files/js/js_7Ukqb3ierdBEL0eowfOKzTkNu-Le97OPm-UqTS5NENU.js', None, None], 'pageCookies': {}, 'pageRedirectEndURL': u'https://lib.asu.edu/', 'pageRedirectHist': [<Response [301]>], 'imageURLs': [u'data:image/png;base64,...', u'data:image/png;base64,...', u'/sites/default/files/general/library_one_search_logo_resize.png', u'/sites/default/files/homepage/BorrowItNowGraphicSmall.jpg', u'/sites/default/files/icons/this.gif', u'/sites/default/files/homepage/featured-resource_2016-07_EducationTechnology.jpg', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/featured-resource_2016-07_EducationTechnology.jpg?itok=nP88-nm_&timestamp=1467996684', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/ArchitectureLibrary20141001_0047.JPG?itok=EMS4XBmp&timestamp=1467073095', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/20160502_SarahDeer_thmb.png?itok=UezUxldS&timestamp=1464302638', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/ArchitectureLibrary_v_49.JPG?itok=KByIQzhB&timestamp=1463531653', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/featured-resource_2016-05_JewishHeritage-AA.jpg?itok=iJGP5Jzl&timestamp=1462221765', u'/sites/default/files/general/libraries_logo_white_footer_60.png', u'/sites/default/files/govdocs/fdlp-emblem-color-25.png', u'data:image/png;base64,...', u'/sites/all/modules/contrib/feedback_simple/feedback_simple.gif']}}
# {'https://lib.asu.edu/': {'pageHeaders': {'Content-Length': '49875', 'X-Drupal-Cache': 'MISS', 'Last-Modified': 'Wed, 27 Jul 2016 04:37:30 GMT', 'Etag': 'W/"1469594250-0"', 'X-Pantheon-Styx-Hostname': 'styx37bdde9b', 'Content-Language': 'en', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'X-Styx-Version': 'StyxGo', 'X-Styx-Req-Id': 'styx-0e11921113afe30760031e7e071d192c', 'Date': 'Wed, 27 Jul 2016 04:37:31 GMT', 'Age': '434', 'X-Varnish': '91658591 97421017', 'Accept-Ranges': 'bytes', 'Server': 'nginx', 'Connection': 'keep-alive', 'X-Pantheon-Endpoint': '60f10b55-cd42-471f-a128-b1576f728538', 'Via': '1.1 varnish-v4', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding, Cookie, Cookie', 'Cache-Control': 'public, max-age=900', 'Content-Type': 'text/html; charset=utf-8', 'X-Generator': 'Drupal 7 (http://drupal.org)'}, 'scriptURLs': [None, None, None, u'//www.asu.edu/asuthemes/4.3/js/asu_header.min.js?v0.22', u'https://lib.asu.edu/sites/default/files/js/js_JLxuxbhhrFRy-sBnijHkR0TGGHgiukMPv94zvDWgQ3g.js', u'https://lib.asu.edu/sites/default/files/js/js_vPfI4qcVjTAPaUE2GX9IXR-oHPw5HBeHmwoIGfDl2HM.js', u'https://lib.asu.edu/sites/default/files/js/js_ZwtHh_UtMhEyIZ7P23uU_tO_tZHXgPG1rk11b_m8s9Y.js', None, None, u'https://lib.asu.edu/sites/default/files/js/js_qqhgYInYpIKc_wtVcwoImiEHiarKSSm4NxmsipAr8D4.js', None, u'https://lib.asu.edu/sites/default/files/js/js_a_XWH2S1EQaU85ypMDyQGiUfzPFez1IOZKxHnhGkv3E.js', None, u'https://lib.asu.edu/sites/default/files/js/js_mgDZNIxOWdpdUe3_wc1OM37QuUmqgsMggaIH1JcGAn4.js', None, None, None, None, None, None, None, None, None, None, None, None, u'//apps.lib.asu.edu/newbooks/js/bookshelf.js', u'//apps.lib.asu.edu/newbooks/js/newbook_image_list.js', u'//apps.lib.asu.edu/newbooks/js/virtualbookshelf.js', u'//apps.lib.asu.edu/newbooks/js/hours.js', u'https://lib.asu.edu/sites/default/files/js/js_7Ukqb3ierdBEL0eowfOKzTkNu-Le97OPm-UqTS5NENU.js', None, None], 'pageCookies': {}, 'pageRedirectEndURL': u'https://lib.asu.edu/', 'pageRedirectHist': [], 'imageURLs': [u'data:image/png;base64,...', u'data:image/png;base64,...', u'/sites/default/files/general/library_one_search_logo_resize.png', u'/sites/default/files/homepage/BorrowItNowGraphicSmall.jpg', u'/sites/default/files/icons/this.gif', u'/sites/default/files/homepage/featured-resource_2016-07_EducationTechnology.jpg', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/featured-resource_2016-07_EducationTechnology.jpg?itok=nP88-nm_&timestamp=1467996684', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/ArchitectureLibrary20141001_0047.JPG?itok=EMS4XBmp&timestamp=1467073095', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/20160502_SarahDeer_thmb.png?itok=UezUxldS&timestamp=1464302638', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/ArchitectureLibrary_v_49.JPG?itok=KByIQzhB&timestamp=1463531653', u'https://lib.asu.edu/sites/default/files/styles/thumbnail_140/public/librarychannel/images/featured-resource_2016-05_JewishHeritage-AA.jpg?itok=iJGP5Jzl&timestamp=1462221765', u'/sites/default/files/general/libraries_logo_white_footer_60.png', u'/sites/default/files/govdocs/fdlp-emblem-color-25.png', u'data:image/png;base64,...', u'/sites/all/modules/contrib/feedback_simple/feedback_simple.gif']}}
#
# ======================================
# (6) Processing: Auburn University Libraries
# Insecure URL: http://www.lib.auburn.edu/
# Secure URL: https://www.lib.auburn.edu/
# {'http://www.lib.auburn.edu/': {'pageHeaders': {'Content-Length': '10095', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=100', 'Server': 'Apache', 'Connection': 'Keep-Alive', 'Date': 'Wed, 27 Jul 2016 04:44:45 GMT', 'Content-Type': 'text/html'}, 'scriptURLs': [u'scripts/js/menuscript.js', u'//www.auburn.edu/template/js/jquery-1.4.2.min.js', u'//www.lib.auburn.edu/scripts/js/searchtabs.js', u'//www.lib.auburn.edu/scripts/swfobject_modified.js', u'//www.lib.auburn.edu/scripts/randomimage/randomimage.js', u'//www.lib.auburn.edu/scripts/js/jquery.lwtCountdown-1.0.js', u'//ajax.googleapis.com/ajax/libs/jquery/1.3.2/jquery.min.js', u'//www.lib.auburn.edu/scripts/js/fadeslideshow.js', None, None, None, None, u'//api.libguides.com/api_searchbox.php?iid=1490&context=object&format=js', None, None, u'//feeds.feedburner.com/WhatsNewAtTheAuburnLibraries?format=sigpro&feedTitle=Your%20Title%20Here', None, None, None], 'pageCookies': {}, 'pageRedirectEndURL': u'http://www.lib.auburn.edu/', 'pageRedirectHist': [], 'imageURLs': [u'http://www.auburn.edu/template/styles/images/headerLogo.png', u'http://lib.auburn.edu/mcb/img/mcb-construction-icon.png', u'http://www.lib.auburn.edu/images/png/socialnetworking2.png']}}
# {'https://www.lib.auburn.edu/': {'pageHeaders': {'Content-Length': '10095', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=100', 'Server': 'Apache', 'Connection': 'Keep-Alive', 'Date': 'Wed, 27 Jul 2016 04:44:46 GMT', 'Content-Type': 'text/html'}, 'scriptURLs': [u'scripts/js/menuscript.js', u'//www.auburn.edu/template/js/jquery-1.4.2.min.js', u'//www.lib.auburn.edu/scripts/js/searchtabs.js', u'//www.lib.auburn.edu/scripts/swfobject_modified.js', u'//www.lib.auburn.edu/scripts/randomimage/randomimage.js', u'//www.lib.auburn.edu/scripts/js/jquery.lwtCountdown-1.0.js', u'//ajax.googleapis.com/ajax/libs/jquery/1.3.2/jquery.min.js', u'//www.lib.auburn.edu/scripts/js/fadeslideshow.js', None, None, None, None, u'//api.libguides.com/api_searchbox.php?iid=1490&context=object&format=js', None, None, u'//feeds.feedburner.com/WhatsNewAtTheAuburnLibraries?format=sigpro&feedTitle=Your%20Title%20Here', None, None, None], 'pageCookies': {}, 'pageRedirectEndURL': u'https://www.lib.auburn.edu/', 'pageRedirectHist': [], 'imageURLs': [u'http://www.auburn.edu/template/styles/images/headerLogo.png', u'http://lib.auburn.edu/mcb/img/mcb-construction-icon.png', u'http://www.lib.auburn.edu/images/png/socialnetworking2.png']}}
#
# ======================================
# (7) Processing: Boston College Libraries
# Insecure URL: http://www.bc.edu/libraries/
# Secure URL: https://www.bc.edu/libraries/
# {'http://www.bc.edu/libraries/': {'pageHeaders': {'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Vary': 'Accept-Encoding', 'Server': 'nginx', 'Last-Modified': 'Mon, 25 Jul 2016 15:35:28 GMT', 'Connection': 'keep-alive', 'Date': 'Wed, 27 Jul 2016 04:44:47 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'text/html', 'Access-Control-Allow-Origin': '*'}, 'scriptURLs': [u'//code.jquery.com/jquery-1.10.0.min.js', u'//code.jquery.com/ui/1.9.2/jquery-ui.min.js', u'//netdna.bootstrapcdn.com/bootstrap/3.1.1/js/bootstrap.min.js', u'/theme/js/bootstrap-hover-dropdown.min.js', u'/theme/js/jquery.hoverIntent.minified.js', u'/theme/js/chosen.jquery.min.js?version=1.1.0', u'/theme/js/modernizr.custom.js', None, None, None, u'//www.google.com/cse/brand?form=cse-search-box&lang=en', u'/theme/js/libraryinfo.js', u'/theme/js/megamenu.js', None, u'/theme/js/nospam.js', u'/theme/js/libhours.js', u'/theme/bcbento/js/typeahead.bundle.min.js', u'/theme/bcbento/js/bclib-typeahead.js', u'/theme/js/classie.js', u'/theme/js/uisearch.js', None, None, u'/theme/js/jquery.carouFredSel-6.2.1.js', None, u'/theme/js/bc-home-chosen.js?version=0.0.2'], 'pageCookies': {}, 'pageRedirectEndURL': u'http://library.bc.edu', 'pageRedirectHist': [<Response [302]>], 'imageURLs': [u'/theme/img/bcheader_title.png', u'/theme/img/librarypane/librarythumbnails_bapst.jpg', u'/theme/img/librarypane/librarythumbnails_burns.jpg', u'/theme/img/librarypane/librarythumbnails_ed.jpg', u'/theme/img/librarypane/librarythumbnails_law.jpg', u'/theme/img/librarypane/librarythumbnails_oconnor.jpg', u'/theme/img/librarypane/librarythumbnails_oneill.jpg', u'/theme/img/librarypane/librarythumbnails_swl.jpg', u'/theme/img/librarypane/librarythumbnails_tml.jpg', u'/theme/img/news/2016-07/mission-thumbs.png', u'/theme/img/news/2016-06/cc-thumbs.png', u'/theme/img/news/2016-05/hale-thumbs.png', u'/theme/img/news/2016-05/here-thumbs.png', u'/theme/img/news/2016-05/going-thumbs.png', u'/theme/img/news/2016-05/rafferty-thumbs.png', u'/theme/img/news/2016-05/voices-thumbs.png', u'/theme/img/news/2016-04/arts-tech-thumbs.png', u'/theme/img/news/2016-04/bowles-thumbs.png', u'/theme/img/news/2016-04/missionary-linguistics.jpg', u'/theme/bcbento/img/loading-bar.gif']}}
# {'https://www.bc.edu/libraries/': {'pageHeaders': {'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Vary': 'Accept-Encoding', 'Server': 'nginx', 'Last-Modified': 'Mon, 25 Jul 2016 15:35:28 GMT', 'Connection': 'keep-alive', 'Date': 'Wed, 27 Jul 2016 04:44:47 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'text/html', 'Access-Control-Allow-Origin': '*'}, 'scriptURLs': [u'//code.jquery.com/jquery-1.10.0.min.js', u'//code.jquery.com/ui/1.9.2/jquery-ui.min.js', u'//netdna.bootstrapcdn.com/bootstrap/3.1.1/js/bootstrap.min.js', u'/theme/js/bootstrap-hover-dropdown.min.js', u'/theme/js/jquery.hoverIntent.minified.js', u'/theme/js/chosen.jquery.min.js?version=1.1.0', u'/theme/js/modernizr.custom.js', None, None, None, u'//www.google.com/cse/brand?form=cse-search-box&lang=en', u'/theme/js/libraryinfo.js', u'/theme/js/megamenu.js', None, u'/theme/js/nospam.js', u'/theme/js/libhours.js', u'/theme/bcbento/js/typeahead.bundle.min.js', u'/theme/bcbento/js/bclib-typeahead.js', u'/theme/js/classie.js', u'/theme/js/uisearch.js', None, None, u'/theme/js/jquery.carouFredSel-6.2.1.js', None, u'/theme/js/bc-home-chosen.js?version=0.0.2'], 'pageCookies': {}, 'pageRedirectEndURL': u'http://library.bc.edu', 'pageRedirectHist': [<Response [302]>], 'imageURLs': [u'/theme/img/bcheader_title.png', u'/theme/img/librarypane/librarythumbnails_bapst.jpg', u'/theme/img/librarypane/librarythumbnails_burns.jpg', u'/theme/img/librarypane/librarythumbnails_ed.jpg', u'/theme/img/librarypane/librarythumbnails_law.jpg', u'/theme/img/librarypane/librarythumbnails_oconnor.jpg', u'/theme/img/librarypane/librarythumbnails_oneill.jpg', u'/theme/img/librarypane/librarythumbnails_swl.jpg', u'/theme/img/librarypane/librarythumbnails_tml.jpg', u'/theme/img/news/2016-07/mission-thumbs.png', u'/theme/img/news/2016-06/cc-thumbs.png', u'/theme/img/news/2016-05/hale-thumbs.png', u'/theme/img/news/2016-05/here-thumbs.png', u'/theme/img/news/2016-05/going-thumbs.png', u'/theme/img/news/2016-05/rafferty-thumbs.png', u'/theme/img/news/2016-05/voices-thumbs.png', u'/theme/img/news/2016-04/arts-tech-thumbs.png', u'/theme/img/news/2016-04/bowles-thumbs.png', u'/theme/img/news/2016-04/missionary-linguistics.jpg', u'/theme/bcbento/img/loading-bar.gif']}}
#
# ======================================
# (8) Processing: Boston Public Library
# Insecure URL: http://www.bpl.org/
# Secure URL: https://www.bpl.org/
# {'http://www.bpl.org/': {'pageHeaders': {'Expires': 'Wed, 11 Jan 1984 05:00:00 GMT', 'access-control-max-age': '3600', 'X-Powered-By': 'ASP.NET, PHP/5.2.12', 'Access-Control-Expose-Headers': 'Etag', 'Server': 'Microsoft-IIS/6.0', 'Connection': 'close', 'Etag': '', 'Cache-Control': 'no-cache, must-revalidate, max-age=0', 'Pragma': 'no-cache', 'access-control-allow-credentials': 'true', 'Date': 'Wed, 27 Jul 2016 04:44:48 GMT', 'access-control-allow-origin': 'http://guides.bpl.org', 'access-control-allow-headers': 'X-Requested-With, Cache-Control', 'Content-Type': 'text/html; charset=utf-8'}, 'scriptURLs': [], 'pageCookies': {}, 'pageRedirectEndURL': u'http://www.bpl.org/', 'pageRedirectHist': [], 'imageURLs': []}}
# something went wrong - more soon ;)
#
# ======================================
# (9) Processing: Boston University Libraries
# Insecure URL: http://www.bu.edu/library/
# Secure URL: https://www.bu.edu/library/
# {'http://www.bu.edu/library/': {'pageHeaders': {'Content-Length': '8582', 'Via': '1.1 www.bu.edu', 'X-BU-Main-Uniqueid': 'V5g8QQrxHD4AAAXCr@kAAAAc', 'X-Powered-By': 'PHP/5.3.27', 'Set-Cookie': 'isMobile=false_1.2; path=/; domain=.bu.edu, wantsMobile=false_1.2_default; path=/; domain=.bu.edu', 'Content-Encoding': 'gzip', 'Vary': 'Cookie,Accept-Encoding,User-Agent', 'Keep-Alive': 'timeout=5, max=100', 'Server': 'Apache/2.2.3 (CentOS) mod_ssl/2.2.3 OpenSSL/0.9.8e-fips-rhel5 PHP/5.3.24', 'Last-Modified': 'Wed, 27 Jul 2016 04:41:47 GMT', 'Connection': 'Keep-Alive', 'Link': '<http://www.bu.edu/library/>; rel=shortlink', 'X-BU-Backend': 'niscms http://ist-wp-app-prod02.bu.edu', 'X-BU-Duration': 'D=15633', 'Cache-Control': 'max-age=178, must-revalidate', 'Date': 'Wed, 27 Jul 2016 04:44:49 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'X-Pingback': 'http://www.bu.edu/library/xmlrpc.php'}, 'scriptURLs': [None, u'//ajax.googleapis.com/ajax/libs/jquery/1.7/jquery.min.js?ver=4.1.12', u'http://www.bu.edu/library/wp-content/mu-plugins/bu-cms/interface/js/outbound_link_tracking.js?ver=4.1.12', None, u'http://www.bu.edu/library/wp-content/mu-plugins/bu-cms/interface/js/download_tracking.js?ver=1.7.1', u'http://www.bu.edu/library/wp-content/themes/bu-library/js/modernizr.js?ver=4.1.12', u'http://www.bu.edu/library/wp-content/themes/bu-library/js/jquery.hoverIntent.minified.js?ver=4.1.12', u'http://www.bu.edu/library/wp-content/themes/bu-library/js/jquery.qtip2.min.js?ver=4.1.12', None, None, None, u'http://www.bu.edu/library/wp-content/themes/bu-library/js/bu-library.js?ver=4.1.12', u'http://www.bu.edu/library/wp-content/themes/bu-library/js/search_tracking.js?ver=4.1.12', None], 'pageCookies': {'wantsMobile': 'false_1.2_default', 'isMobile': 'false_1.2'}, 'pageRedirectEndURL': u'http://www.bu.edu/library/', 'pageRedirectHist': [], 'imageURLs': []}}
# {'https://www.bu.edu/library/': {'pageHeaders': {'Content-Length': '8626', 'Via': '1.1 www.bu.edu', 'X-BU-Main-Uniqueid': 'V5g8QQrxHD4AAAXCr@wAAAAc', 'Content-Security-Policy': 'upgrade-insecure-requests', 'X-Powered-By': 'PHP/5.3.24', 'Set-Cookie': 'isMobile=false_1.2; path=/; domain=.bu.edu, wantsMobile=false_1.2_default; path=/; domain=.bu.edu', 'Content-Encoding': 'gzip', 'Vary': 'Cookie,Accept-Encoding,User-Agent', 'Keep-Alive': 'timeout=5, max=100', 'Server': 'Apache/2.2.3 (CentOS) mod_ssl/2.2.3 OpenSSL/0.9.8e-fips-rhel5 PHP/5.3.24', 'Content-Security-Policy-Report-Only': "default-src https: data: 'unsafe-eval' 'unsafe-inline'; report-uri https://3j40yr1pel.execute-api.us-east-1.amazonaws.com/prod/report-only", 'Last-Modified': 'Wed, 27 Jul 2016 04:41:48 GMT', 'Connection': 'Keep-Alive', 'Link': '<https://www.bu.edu/library/>; rel=shortlink', 'X-BU-Backend': 'niscms http://ist-wp-app-prod01.bu.edu', 'X-BU-Duration': 'D=17837', 'Cache-Control': 'max-age=179, must-revalidate', 'Date': 'Wed, 27 Jul 2016 04:44:49 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'X-Pingback': 'https://www.bu.edu/library/xmlrpc.php'}, 'scriptURLs': [None, u'//ajax.googleapis.com/ajax/libs/jquery/1.7/jquery.min.js?ver=4.1.12', u'https://www.bu.edu/library/wp-content/mu-plugins/bu-cms/interface/js/outbound_link_tracking.js?ver=4.1.12', None, u'https://www.bu.edu/library/wp-content/mu-plugins/bu-cms/interface/js/download_tracking.js?ver=1.7.1', u'https://www.bu.edu/library/wp-content/themes/bu-library/js/modernizr.js?ver=4.1.12', u'https://www.bu.edu/library/wp-content/themes/bu-library/js/jquery.hoverIntent.minified.js?ver=4.1.12', u'https://www.bu.edu/library/wp-content/themes/bu-library/js/jquery.qtip2.min.js?ver=4.1.12', None, None, None, u'https://www.bu.edu/library/wp-content/themes/bu-library/js/bu-library.js?ver=4.1.12', u'https://www.bu.edu/library/wp-content/themes/bu-library/js/search_tracking.js?ver=4.1.12', None], 'pageCookies': {'wantsMobile': 'false_1.2_default', 'isMobile': 'false_1.2'}, 'pageRedirectEndURL': u'https://www.bu.edu/library/', 'pageRedirectHist': [], 'imageURLs': []}}
#
# ======================================
# (10) Processing: Brigham Young University Library
# Insecure URL: http://www.lib.byu.edu/
# Secure URL: https://www.lib.byu.edu/
# {'http://www.lib.byu.edu/': {'pageHeaders': {'Content-Length': '6335', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ZOMBIE_ID=0d75cc18-c529-40e6-9f62-71853122f41e; expires=Sat, 25-Jul-2026 04:44:51 GMT; path=/; domain=lib.byu.edu', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=98', 'Server': 'Apache', 'Connection': 'Keep-Alive', 'Pragma': 'no-cache', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Date': 'Wed, 27 Jul 2016 04:44:51 GMT', 'Content-Type': 'text/html'}, 'scriptURLs': [None, u'https://media.lib.byu.edu/assets/js/jquery/jquery-1.9.1.js', u'https://media.lib.byu.edu/assets/js/loader/hbll-3.0.11,search-3.0.12,nav-3.0.3,formspackage-1.2,advsearch-3.0,honeybell-1.0,mousetrap-1.0', None, None, u'https://media.lib.byu.edu/assets/js/omniture/s_code_remote.js'], 'pageCookies': {'ZOMBIE_ID': '0d75cc18-c529-40e6-9f62-71853122f41e'}, 'pageRedirectEndURL': u'https://lib.byu.edu/', 'pageRedirectHist': [<Response [301]>, <Response [301]>, <Response [302]>, <Response [302]>, <Response [302]>, <Response [302]>, <Response [302]>, <Response [302]>], 'imageURLs': [u'https://media.lib.byu.edu/assets/images/hbll/3.0/hbll-logo.svg', u'https://media.lib.byu.edu/assets/images/hbll/3.0/byu-hbll-logo-full.svg', u'https://sites.lib.byu.edu/news/wp-content/uploads/sites/10/2016/07/Mintel-Dog.jpg', u'https://sites.lib.byu.edu/news/wp-content/uploads/sites/10/2016/05/Icon-for-Fashion-Story.jpg', u'https://media.lib.byu.edu/assets/images/exhibits/1.0/who-moved-my-media.jpg', u'https://sites.lib.byu.edu/art/wp-content/uploads/sites/63/2016/03/1a-150x150.jpg']}}
# {'https://www.lib.byu.edu/': {'pageHeaders': {'Content-Length': '6335', 'Content-Encoding': 'gzip', 'Set-Cookie': 'ZOMBIE_ID=76ca2448-bb31-4c2b-bbe1-aa6d6dcbdce8; expires=Sat, 25-Jul-2026 04:44:53 GMT; path=/; domain=lib.byu.edu', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=98', 'Server': 'Apache', 'Connection': 'Keep-Alive', 'Pragma': 'no-cache', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Date': 'Wed, 27 Jul 2016 04:44:53 GMT', 'Content-Type': 'text/html'}, 'scriptURLs': [None, u'https://media.lib.byu.edu/assets/js/jquery/jquery-1.9.1.js', u'https://media.lib.byu.edu/assets/js/loader/hbll-3.0.11,search-3.0.12,nav-3.0.3,formspackage-1.2,advsearch-3.0,honeybell-1.0,mousetrap-1.0', None, None, u'https://media.lib.byu.edu/assets/js/omniture/s_code_remote.js'], 'pageCookies': {'ZOMBIE_ID': '76ca2448-bb31-4c2b-bbe1-aa6d6dcbdce8'}, 'pageRedirectEndURL': u'https://lib.byu.edu/', 'pageRedirectHist': [<Response [301]>, <Response [302]>, <Response [302]>, <Response [302]>, <Response [302]>, <Response [302]>, <Response [302]>], 'imageURLs': [u'https://media.lib.byu.edu/assets/images/hbll/3.0/hbll-logo.svg', u'https://media.lib.byu.edu/assets/images/hbll/3.0/byu-hbll-logo-full.svg', u'https://sites.lib.byu.edu/news/wp-content/uploads/sites/10/2016/07/Mintel-Dog.jpg', u'https://sites.lib.byu.edu/news/wp-content/uploads/sites/10/2016/05/Icon-for-Fashion-Story.jpg', u'https://media.lib.byu.edu/assets/images/exhibits/1.0/who-moved-my-media.jpg', u'https://sites.lib.byu.edu/art/wp-content/uploads/sites/63/2016/03/1a-150x150.jpg']}}
#
# ======================================
# (11) Processing: University of British Columbia Library
# Insecure URL: http://www.library.ubc.ca/
# Secure URL: https://www.library.ubc.ca/
# {'http://www.library.ubc.ca/': {'pageHeaders': {'Content-Length': '11655', 'Content-Encoding': 'gzip', 'X-Powered-By': 'PHP/5.3.2-1ubuntu4.30', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=100', 'Server': 'Apache/2.2.14 (Ubuntu)', 'Connection': 'Keep-Alive', 'Date': 'Wed, 27 Jul 2016 04:44:54 GMT', 'Content-Type': 'text/html'}, 'scriptURLs': [u'https://ajax.googleapis.com/ajax/libs/jquery/1.8.1/jquery.min.js', u'https://ajax.googleapis.com/ajax/libs/jqueryui/1.8.12/jquery-ui.min.js', u'https://clf.library.ubc.ca/7.0.2/colorbox/jquery.colorbox.js', u'https://clf.library.ubc.ca/7.0.2/modernizr/modernizr.js', u'https://cdn.ubc.ca/clf/7.0.2/js/ubc-clf.min.js', u'https://clf.library.ubc.ca/7.0.2/js/library-ui.js', u'https://www.google.com/jsapi?key=ABQIAAAAoRs91XgpKw60K4liNrOHoBStNMhZCa0lqZKLUDgzjZGRsKl38xSnSmVmaulnWVdBLItzW4KsddHCzA', u'http://clf.library.ubc.ca/js/jquery.cycle.min.js', u'http://clf.library.ubc.ca/js/jquery.vticker.js', u'http://clf.library.ubc.ca/js/organictabs.jquery.js', u'http://clf.library.ubc.ca/js/home.min.js?8113', u'http://www.google.com/jsapi', None, u'http://hours.library.ubc.ca/widget-hours-js.php?display=homepage&1469594694', None, None], 'pageCookies': {}, 'pageRedirectEndURL': u'http://www.library.ubc.ca/', 'pageRedirectHist': [], 'imageURLs': [u'http://about.library.ubc.ca/files/2016/07/hp-feature-web-visual.jpg', u'http://about.library.ubc.ca/files/2016/07/RMO.jpg', u'http://about.library.ubc.ca/files/2016/06/LibraryAwards.jpg', u'http://about.library.ubc.ca/files/2016/03/BookOfHours_sm.jpg']}}
# {'https://www.library.ubc.ca/': {'pageHeaders': {'Content-Length': '11655', 'Content-Encoding': 'gzip', 'X-Powered-By': 'PHP/5.3.2-1ubuntu4.30', 'Vary': 'Accept-Encoding', 'Keep-Alive': 'timeout=15, max=100', 'Server': 'Apache/2.2.14 (Ubuntu)', 'Connection': 'Keep-Alive', 'Date': 'Wed, 27 Jul 2016 04:44:54 GMT', 'Content-Type': 'text/html'}, 'scriptURLs': [u'https://ajax.googleapis.com/ajax/libs/jquery/1.8.1/jquery.min.js', u'https://ajax.googleapis.com/ajax/libs/jqueryui/1.8.12/jquery-ui.min.js', u'https://clf.library.ubc.ca/7.0.2/colorbox/jquery.colorbox.js', u'https://clf.library.ubc.ca/7.0.2/modernizr/modernizr.js', u'https://cdn.ubc.ca/clf/7.0.2/js/ubc-clf.min.js', u'https://clf.library.ubc.ca/7.0.2/js/library-ui.js', u'https://www.google.com/jsapi?key=ABQIAAAAoRs91XgpKw60K4liNrOHoBStNMhZCa0lqZKLUDgzjZGRsKl38xSnSmVmaulnWVdBLItzW4KsddHCzA', u'http://clf.library.ubc.ca/js/jquery.cycle.min.js', u'http://clf.library.ubc.ca/js/jquery.vticker.js', u'http://clf.library.ubc.ca/js/organictabs.jquery.js', u'http://clf.library.ubc.ca/js/home.min.js?8113', u'http://www.google.com/jsapi', None, u'http://hours.library.ubc.ca/widget-hours-js.php?display=homepage&1469594694', None, None], 'pageCookies': {}, 'pageRedirectEndURL': u'https://www.library.ubc.ca/', 'pageRedirectHist': [], 'imageURLs': [u'http://about.library.ubc.ca/files/2016/07/hp-feature-web-visual.jpg', u'http://about.library.ubc.ca/files/2016/07/RMO.jpg', u'http://about.library.ubc.ca/files/2016/06/LibraryAwards.jpg', u'http://about.library.ubc.ca/files/2016/03/BookOfHours_sm.jpg']}}
#
# ======================================
